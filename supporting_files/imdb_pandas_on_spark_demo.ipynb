# %%
import pyspark.pandas as ps

df = ps.read_csv("../datasets/name.basics.tsv.gz",sep='\t', header=0)
# Out:
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
# c:\Users\alonso\anaconda3\envs\pyspark-test\lib\site-packages\pyspark\pandas\utils.py:975: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `read_csv`, the default index is attached which can cause additional overhead.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
df.head()
# Out:
#       nconst      primaryName birthYear deathYear                    primaryProfession                           knownForTitles
# 0  nm0000001     Fred Astaire      1899      1987       soundtrack,actor,miscellaneous  tt0031983,tt0053137,tt0050419,tt0072308
# 1  nm0000002    Lauren Bacall      1924      2014                   actress,soundtrack  tt0071877,tt0117057,tt0037382,tt0038355
# 2  nm0000003  Brigitte Bardot      1934        \N  actress,soundtrack,music_department  tt0054452,tt0049189,tt0056404,tt0057345
# 3  nm0000004     John Belushi      1949      1982              actor,soundtrack,writer  tt0072562,tt0077975,tt0080455,tt0078723
# 4  nm0000005   Ingmar Bergman      1918      2007                writer,director,actor  tt0050976,tt0050986,tt0060827,tt0083922

# %%
df.count()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# File c:\Users\alonso\anaconda3\envs\pyspark-test\lib\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File c:\Users\alonso\anaconda3\envs\pyspark-test\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
# ...

# %%
new_df = df.where(df["primaryName"] == "Brigitte Bardot").dropna()

# %%
new_df
# Out:
#         nconst      primaryName birthYear deathYear                    primaryProfession                           knownForTitles
# 0          NaN              NaN       NaN       NaN                                  NaN                                      NaN
# 1          NaN              NaN       NaN       NaN                                  NaN                                      NaN
# 2    nm0000003  Brigitte Bardot      1934        \N  actress,soundtrack,music_department  tt0054452,tt0049189,tt0056404,tt0057345
# 3          NaN              NaN       NaN       NaN                                  NaN                                      NaN
# 4          NaN              NaN       NaN       NaN                                  NaN                                      NaN
# 5          NaN              NaN       NaN       NaN                                  NaN                                      NaN
# ...

# %%
ps.sql("SELECT * FROM {df} where primaryName='Brigitte Bardot'",df=df)
# Out:
#       nconst      primaryName birthYear deathYear                    primaryProfession                           knownForTitles
# 0  nm0000003  Brigitte Bardot      1934        \N  actress,soundtrack,music_department  tt0054452,tt0049189,tt0056404,tt0057345
